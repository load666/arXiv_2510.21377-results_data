# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from colossus.cosmology import cosmology
from scipy.optimize import fsolve
import emcee
import pyccl as ccl
import random
from colossus.lss import bias
from matplotlib.ticker import LogLocator, ScalarFormatter
import seaborn as sns
import pandas as pd

# %%
import math

def atan2_math(a, b):
    return 2 * math.atan(a / (math.sqrt(b**2 + a**2) + b))

a, b = 1, 1.9
print(math.atan2(a, b), atan2_math(a, b))  # 输出相同

a, b = -1, -1.3
print(math.atan2(a, b), atan2_math(a, b))  # 输出相同
# Out:
# 0.48447792903702325 0.4844779290370233
# -2.485897027348257 -2.485897027348257

# %%
h=0.6774
omega_b=0.0486
omega_m=0.3089
omega_c=omega_m-omega_b
omega_l=0.6911
ns=0.9667
sigma8=0.8159
my_cosmo = {'flat': True, 'H0': h*100, 'Om0': omega_c, 'Ob0': omega_b, 'sigma8': sigma8, 'ns': ns}
cosmo2 = cosmology.setCosmology('my_cosmo', **my_cosmo)

cosmo = ccl.Cosmology(Omega_c=omega_c, Omega_b=omega_b, h=h, sigma8=sigma8, n_s=ns,transfer_function='boltzmann_camb')

# %%
def mcmcfit(x, y, invcov):

    # 定义线性模型
    def model(params, x):
        b = params
        return b

    # 定义对数似然函数
    def log_likelihood(params, x, y, invcov):
        model_y = model(params, x)
        diff=np.mat(y - model_y)
        return -0.5 * np.dot(diff, np.dot(invcov, diff.T))

    # 定义对数先验概率
    def log_prior(params):
        b = params
        if -10. < b < 10.:
            return 0.0
        return -np.inf

    # 定义对数后验概率
    def log_probability(params, x, y, invcov):
        lp = log_prior(params)
        if not np.isfinite(lp):
            return -np.inf
        return lp + log_likelihood(params, x, y, invcov)

    # 初始化参数
    nwalkers = 10
    p0 = np.random.rand(nwalkers, 1) * 2 - 1

    # 设置MCMC采样器
    sampler = emcee.EnsembleSampler(nwalkers, 1, log_probability, args=(x, y, invcov))

    # 运行MCMC采样
    sampler.run_mcmc(p0, 5000, progress=True)
    samples = sampler.get_chain()

    # 计算参数的均值和标准差
    nburn = 200
    quantiles = np.array([16., 50., 84.])

    parameter_results = np.percentile(samples[nburn:, :].flatten(), quantiles)
    mean_b = parameter_results[1]
    std_b_minus = parameter_results[1] - parameter_results[0]
    std_b_plus = parameter_results[2] - parameter_results[1]

    return mean_b, std_b_minus, std_b_plus,samples[nburn:, :].flatten()

# %%
clight=299792.458 #km/s
h=0.6774
omega_b=0.0486
omega_m=0.3089
omega_c=omega_m-omega_b
omega_l=0.6911
ns=0.9667
sigma8=0.8159
my_cosmo = {'flat': True, 'H0': h*100, 'Om0': omega_c, 'Ob0': omega_b, 'sigma8': sigma8, 'ns': ns}
cosmo2 = cosmology.setCosmology('my_cosmo', **my_cosmo)

def xi_mm(rr,a):
    if(len(rr) == 1 and rr[0] < 1e-3):
        return cosmo2.correlationFunction([1e-3], z=1./a-1., derivative=False, ps_args={'model': 'camb'})
    else:
        return cosmo2.correlationFunction(rr, z=1./a-1., derivative=False, ps_args={'model': 'camb'})

def zeta_0(rr,a):
    zeta0=(1+1.17*xi_mm(rr,a))**1.49/(1+0.69*xi_mm(rr,a))**2.09
    return zeta0

def r_phi(a):
    phi=0.9
    def zeta0_ximm(rr):
        ztmm=zeta_0(rr,a)*xi_mm(rr,a)-10**phi
        return ztmm
    rphi=fsolve(zeta0_ximm, 1.)
    return rphi

def zeta(rr,a):
    newr=np.zeros_like(rr)
    rp=r_phi(a)
    for i in range(len(rr)):
        if(rr[i] < rp):
            newr[i]=rp
        else:
            newr[i]=rr[i]
    zt=zeta_0(newr,a)
    return zt
    
def wp(rp, z):
    ppi=np.linspace(0,100,1000) #Mpc/h
    ppi=(ppi[1:]+ppi[:-1])/2.
    dpi=ppi[1]-ppi[0]
    wps=[]
    a=1/(1+z)
    for i in range(len(rp)):
        r=np.sqrt(ppi**2+rp[i]**2)
        zeta0=zeta(r,a)
        wps.append(np.sum(zeta0*zeta0*xi_mm(r,a))*dpi*2)
    return np.array(wps)
    
	
def decodePairs(pairs, njack, rbin, pibin):
    # pair data format
    # (njack_0, rp_0, pi_0), (njack_1, , rp_0, pi_0), ... (njack_n, , rp_0, pi_0)
    # (njack_0, rp_0, pi_1), (njack_1, , rp_0, pi_1), ... (njack_n, , rp_0, pi_1)
    # ...
    # (njack_0, rp_0, pi_n), (njack_1, , rp_0, pi_n), ... (njack_n, , rp_0, pi_n)
    # (njack_0, rp_1, pi_0), (njack_1, , rp_1, pi_0), ... (njack_n, , rp_1, pi_0)
    # ... ...
    # (njack_0, rp_n, pi_n), (njack_1, , rp_n, pi_n), ... (njack_n, , rp_n, pi_n)
    mat_pairs = np.zeros((njack, rbin, pibin))
    for i in range(rbin):
        for j in range(pibin):
            for k in range(njack):
                mat_pairs[k,i,j] = pairs[njack*(i*pibin+j)+k]
    return mat_pairs

def calcJKCov(wp_jk):
    n_r = wp_jk.shape[0]
    n_jk = wp_jk.shape[1]
    wp_mean = np.average(wp_jk, axis = 1)
    cov = np.zeros((n_r, n_r))
    for i in range(cov.shape[0]):
        for j in range(cov.shape[1]):
            cov[i,j] = np.sum((wp_jk[i]-wp_mean[i])*(wp_jk[j]-wp_mean[j]))
    cov *= (n_jk-1.)/n_jk
    return wp_mean,cov


def cal_wp_bias_ratio(rbin, pimax, pibin,pimaxint, bias1,bias2,njack, outputdir1,outputdir2):
    deltapi= float(pimax)/float(pibin)
    
    dd_file=outputdir1+"pairs_dd.dat"
    dr_file=outputdir1+"pairs_dr.dat"
    rr_file=outputdir1+"pairs_rr.dat"
    data=np.loadtxt(outputdir1+"num_gal_ran.dat")
    ngal=data[0]
    nran=data[1]
    print(ngal,nran)
    dd = np.fromfile(dd_file, dtype = float)
    dd = decodePairs(dd, njack, rbin, pibin)/(ngal*ngal)
    dr = np.fromfile(dr_file, dtype = float)
    dr = decodePairs(dr, njack, rbin, pibin)/(ngal*nran)
    rr = np.fromfile(rr_file, dtype = float)
    rr = decodePairs(rr, njack, rbin, pibin)/(nran*nran)

    xi = (dd - 2.*dr + rr)/rr
    #xi = dd/rr-1
    wp_jk1 = 2.*np.sum(xi[:,:,:pimaxint], axis = 2)*deltapi
    wp1,cov1 = calcJKCov(np.transpose(wp_jk1))

    dd_file=outputdir2+"pairs_dd.dat"
    dr_file=outputdir2+"pairs_dr.dat"
    rr_file=outputdir2+"pairs_rr.dat"
    data=np.loadtxt(outputdir2+"num_gal_ran.dat")
    ngal=data[0]
    nran=data[1]
    print(ngal,nran)
    dd = np.fromfile(dd_file, dtype = float)
    dd = decodePairs(dd, njack, rbin, pibin)/(ngal*ngal)
    dr = np.fromfile(dr_file, dtype = float)
    dr = decodePairs(dr, njack, rbin, pibin)/(ngal*nran)
    rr = np.fromfile(rr_file, dtype = float)
    rr = decodePairs(rr, njack, rbin, pibin)/(nran*nran)

    xi = (dd - 2.*dr + rr)/rr
    #xi = dd/rr-1
    wp_jk2 = 2.*np.sum(xi[:,:,:pimaxint], axis = 2)*deltapi
    wp2,cov2 = calcJKCov(np.transpose(wp_jk2))

    ratio,cov = calcJKCov(np.transpose(np.sqrt((wp_jk2/bias2**2)/(wp_jk1/bias1**2))))
    return wp1,np.sqrt(np.diag(cov1)),wp2,np.sqrt(np.diag(cov2)),ratio, np.sqrt(np.diag(cov)),cov, wp_jk1/wp_jk2


def cal_wp_bias_ratio_3(rbin, pimax, pibin,pimaxint,njack, outputdir1,outputdir2):
    deltapi= float(pimax)/float(pibin)
    
    dd_file=outputdir1+"pairs_dd.dat"
    dr_file=outputdir1+"pairs_dr.dat"
    rr_file=outputdir1+"pairs_rr.dat"
    data=np.loadtxt(outputdir1+"num_gal_ran.dat")
    ngal=data[0]
    nran=data[1]
    print(ngal,nran)
    dd = np.fromfile(dd_file, dtype = float)
    dd = decodePairs(dd, njack, rbin, pibin)/(ngal*ngal)
    dr = np.fromfile(dr_file, dtype = float)
    dr = decodePairs(dr, njack, rbin, pibin)/(ngal*nran)
    rr = np.fromfile(rr_file, dtype = float)
    rr = decodePairs(rr, njack, rbin, pibin)/(nran*nran)

    xi = (dd - 2.*dr + rr)/rr
    #xi = dd/rr-1
    wp_jk1 = 2.*np.sum(xi[:,:,:pimaxint], axis = 2)*deltapi
    wp1,cov1 = calcJKCov(np.transpose(wp_jk1))

    dd_file=outputdir2+"pairs_dd.dat"
    dr_file=outputdir2+"pairs_dr.dat"
    rr_file=outputdir2+"pairs_rr.dat"
    data=np.loadtxt(outputdir2+"num_gal_ran.dat")
    ngal=data[0]
    nran=data[1]
    print(ngal,nran)
    dd = np.fromfile(dd_file, dtype = float)
    dd = decodePairs(dd, njack, rbin, pibin)/(ngal*ngal)
    dr = np.fromfile(dr_file, dtype = float)
    dr = decodePairs(dr, njack, rbin, pibin)/(ngal*nran)
    rr = np.fromfile(rr_file, dtype = float)
    rr = decodePairs(rr, njack, rbin, pibin)/(nran*nran)

    xi = (dd - 2.*dr + rr)/rr
    #xi = dd/rr-1
    wp_jk2 = 2.*np.sum(xi[:,:,:pimaxint], axis = 2)*deltapi
    wp2,cov2 = calcJKCov(np.transpose(wp_jk2))

    ratio,cov = calcJKCov(np.transpose(np.sqrt(wp_jk2/wp_jk1)))
    return wp1,np.sqrt(np.diag(cov1)),wp2,np.sqrt(np.diag(cov2)),ratio, np.sqrt(np.diag(cov)),cov, np.sqrt(wp_jk2/wp_jk1)


def fit_constant_with_cov(r, C_r):
    """
    广义最小二乘拟合常数模型 r_b0
    r : array_like, shape (n,)
        数据向量
    C_r : array_like, shape (n, n)
        数据的协方差矩阵

    Returns
    -------
    r_b0 : float
        拟合得到的常数
    sigma_r_b0 : float
        拟合常数的不确定性（标准差）
    """
    r = np.asarray(r)
    C_r = np.asarray(C_r)
    
    # 计算逆协方差矩阵
    Cinv = np.linalg.inv(C_r)
    
    ones = np.ones_like(r)
    
    numerator = ones @ Cinv @ r
    denominator = ones @ Cinv @ ones
    
    r_b0 = numerator / denominator
    sigma_r_b0 = np.sqrt(1.0 / denominator)
    
    return r_b0, sigma_r_b0

    

def fit_Chi2(r, C_r):
    """
    广义最小二乘拟合常数模型 r_b0
    r : array_like, shape (n,)
        数据向量
    C_r : array_like, shape (n, n)
        数据的协方差矩阵

    Returns
    -------
    r_b0 : float
        拟合得到的常数
    sigma_r_b0 : float
        拟合常数的不确定性（标准差）
    """
    r = np.asarray(r)
    C_r = np.asarray(C_r)
    
    # 计算逆协方差矩阵
    Cinv = np.linalg.inv(C_r)
    
    ones = r-np.ones_like(r)
    denominator = ones @ Cinv @ ones
    
    return np.sqrt(denominator)

# %%
def shrink_cov(C):
    lamb = 0.05
    return (1-lamb)*C + lamb*np.diag(np.diag(C))
    
njk=100
M1=13.42529766
M2=13.80874081
zz=[0.3183509812149577,0.32184142323886783]
Ab_ggl=[0.91,0.82]
delta_Mh=200
data_path1="/data/liuzhj/assbias/clustering/diff_Ms/diff_ms-total/ggl-chains-mag/"
samples=[]
for isig in range(2):
    file_path1 = data_path1 + "chain_10000_steps-intpl-M-c-rs-fc-bh-n"+str(isig+1)+".npz"
    data1 = np.load(file_path1)
    samples1 = np.array(data1['arr_0'])
    nburn=int(samples1.shape[0]*0.1)
    random.shuffle(samples1[nburn:,0])
    bias_t10=bias.haloBias(10**samples1[nburn:,0], zz[isig], mdef='200m', model='tinker10')
    #bias_t10=ccl.massfunction.halo_bias(cosmo, 10**samples1[nburn:,0]/h, a=1/(1+zz1), overdensity=delta_Mh)
    samples.append(bias_t10)
chains_ratio_t10=samples[0]/samples[1]
rb_ggl=np.mean(chains_ratio_t10)
rb_ggl_var=np.var(chains_ratio_t10)

dtype = [('R', float), ('Rmin', float), ('Rmax', float), ('wp', float), ('wp_err', float)]
fig, axs = plt.subplots(
    3, 1,
    figsize=(5.5, 8.5),
    sharex=True,
    gridspec_kw={'height_ratios': [4, 3, 1.5]}   # 3:2:1 的高度比
)

data_dir="/data/liuzhj/assbias/clustering/diff_Ms/diff_ms-total/"
dir1=data_dir+"results-specz-mag-sub1-2/"
dir2=data_dir+"results-specz-mag-sub2-2/"
wp1_100,wp_err1_100,wp2_100,wp_err2_100,ratio_100, ratio_err_100, ratio_cov_100, ratio_jk_100 = cal_wp_bias_ratio_3(rbin = 8, pimax = 200, pimaxint=100,pibin = 200,njack = njk, outputdir1=dir1,outputdir2=dir2)
wp1_200,wp_err1_200,wp2_200,wp_err2_200,ratio_200, ratio_err_200, ratio_cov_200, ratio_jk_200 = cal_wp_bias_ratio_3(rbin = 8, pimax = 200, pimaxint=50,pibin = 200, njack = njk, outputdir1=dir1,outputdir2=dir2)


ratio_cov_100=(ratio_cov_100*(rb_ggl_var+rb_ggl**2)+rb_ggl_var*np.outer(ratio_100, ratio_100))#*np.eye(9)
ratio_cov_200=(ratio_cov_200*(rb_ggl_var+rb_ggl**2)+rb_ggl_var*np.outer(ratio_200, ratio_200))#*np.eye(9)
ratio_cov_100=shrink_cov(ratio_cov_100)
ratio_err_100=np.sqrt(np.diag(ratio_cov_100))
ratio_err_200=np.sqrt(np.diag(ratio_cov_200))
ratio_100=ratio_100*rb_ggl
ratio_200=ratio_200*rb_ggl

#ratio_100,ratio_cov_100=build_Cr_from_chain_and_jk(chains_ratio_t10, ratio_jk_100, jitter=1e-12, use_log=False)
#ratio_cov_100=shrink_cov(ratio_cov_100)
#ratio_err_100=np.sqrt(np.diag(ratio_cov_100))

rb0,rb0_err=fit_constant_with_cov(ratio_100, ratio_cov_100)
print('gls',rb0,rb0_err)
ind_large=4
rb0,rb0_err=fit_constant_with_cov(ratio_100[4:], ratio_cov_100[4:,4:])
print('gls large-scale',rb0,rb0_err)

file_path = dir1 + "wp_results.dat"
data = np.genfromtxt(file_path, delimiter=' ', comments='#', dtype=dtype)
rcen=data['R']

bias1=bias.haloBias(10**M1, zz[0], mdef='200m', model='tinker10')*Ab_ggl[0]
bias2=bias.haloBias(10**M2, zz[1], mdef='200m', model='tinker10')*Ab_ggl[1]
axs[0].plot(rcen,bias1**2*wp(rcen, zz[0]),'b--')
axs[0].plot(rcen,bias2**2*wp(rcen, zz[1]),'r--')
axs[0].errorbar(rcen,wp1_100,yerr=wp_err1_100,label=r"low-$L$",fmt='o',capsize=4,c='b')
axs[0].errorbar(rcen,wp2_100,yerr=wp_err2_100,label=r"high-$L$",fmt='o',capsize=4,c='r')
axs[0].set_xscale('log')
axs[0].set_yscale('log')
    
axs[1].errorbar(rcen,ratio_100,yerr=ratio_err_100,fmt='o',capsize=4,c='m',label=r'$\Pi_{\rm max}=100{\rm Mpc}/h$')
axs[1].errorbar(rcen*1.05,ratio_200,yerr=ratio_err_200,fmt='o',capsize=4,c='gray',markerfacecolor='none',label=r'$\Pi_{\rm max}=50{\rm Mpc}/h$')
axs[1].legend(fontsize=12)

inv_ratio_cov=np.linalg.inv(ratio_cov_100)
b,bem,bep,chains22 = mcmcfit(rcen,ratio_100,inv_ratio_cov)
print(b,bem,bep)
text_str = r"$r_{{b0}} = {:.2f}^{{+{:.2f}}}_{{-{:.2f}}}$".format(b, bep, bem)
diff=np.mat(ratio_100-1)
snr=np.sqrt(np.dot(diff, np.dot(inv_ratio_cov, diff.T)))[0,0]
print("S/N: ",snr,fit_Chi2(ratio_100,ratio_cov_100))

inv_ratio_cov=np.linalg.inv(ratio_cov_100[4:,4:])
b,bem,bep,chains22 = mcmcfit(rcen[4:],ratio_100[4:],inv_ratio_cov)
print(b,bem,bep)
text_str2 = r"$r_{{b0}}^{{large}} = {:.2f}^{{+{:.2f}}}_{{-{:.2f}}}$".format(b, bep, bem)
diff=np.mat(ratio_100[4:]-1)
snr=np.sqrt(np.dot(diff, np.dot(inv_ratio_cov, diff.T)))[0,0]
print("large-scale S/N: ",snr,fit_Chi2(ratio_100,ratio_cov_100))

axs[1].plot([0.1,100],np.ones(2),'--',c='k')
#axs[1].plot([0.1,100],np.ones(2)*b,'-',c='darkorange')
#axs[1].fill_between([0.1,100],np.ones(2)*(b-bem),np.ones(2)*(b+bem),alpha=0.4,color='darkorange')

axs[1].set_xscale('log')
axs[1].text(3.3,1.25,text_str,fontsize=14)
axs[1].text(3.3,1.14,text_str2,fontsize=14)
#axs[1].text(2.3,1.25,'S/N = '+str(format(snr, '.1f')),fontsize=14)

axs[2].set_xlabel(r'$R$ [Mpc/$h$]',fontsize=14)
axs[1].set_ylim(0.7,1.35)

axs[0].tick_params(axis='both', which='both', direction='in', top=True, right=True)
axs[1].tick_params(axis='both', which='both', direction='in', top=True, right=True)
axs[2].tick_params(axis='both', which='both', direction='in', top=True, right=True)
axs[1].set_xlim(2.8,48)
axs[0].legend(fontsize=14)
axs[0].set_ylabel('$w_p (R)$',fontsize=14)
axs[1].set_ylabel('$r_b (R)$',fontsize=14)
    
ratio_ratio,cov = calcJKCov(np.transpose(np.sqrt(ratio_jk_200/ratio_jk_100)))
ratio_ratio_err = np.sqrt(np.diag(cov))


inv_ratio_cov=np.linalg.inv(cov)
diff=np.mat(ratio_ratio-1)
snr=np.sqrt(np.dot(diff, np.dot(inv_ratio_cov, diff.T)))[0,0]
print("projection S/N: ",snr)

rb0,rb0_err=fit_constant_with_cov(ratio_ratio, cov)
print('gls',rb0,rb0_err)

axs[2].plot([0.1,100],np.ones(2),'-',c='gray')
axs[2].errorbar(rcen,ratio_ratio,yerr=ratio_ratio_err,fmt='o',capsize=4,c='m')
axs[2].set_ylim(0.94,1.06)
axs[2].set_ylabel(r'$r_b^{\rm 50}/r_b^{\rm 100}$',fontsize=14)
axs[0].grid(True, which='major', linestyle='-', alpha=0.7)
axs[0].grid(True, which='minor', linestyle='--', alpha=0.5)

plt.subplots_adjust(wspace=0,hspace=0)
plt.savefig('wp-diff_mag-specz.png',bbox_inches = 'tight',dpi=200)
# Out:
# 25512.0 255120.0
# 23176.0 231760.0
# 25512.0 255120.0
# 23176.0 231760.0
# gls 0.8847733002076797 0.05987453301421225
# gls large-scale 0.9028262398103917 0.06684304843270099
# 100%|██████████| 5000/5000 [00:02<00:00, 2212.19it/s]
# 0.8852034933432082 0.059552536112775556 0.05901718335301931
# S/N:  3.2691015254167013 3.269101525416701
# 100%|██████████| 5000/5000 [00:02<00:00, 2200.64it/s]
# 0.902224418116566 0.0677058309141213 0.06737884795408555
# large-scale S/N:  2.015837857299698 3.269101525416701
# projection S/N:  3.138033585772331
# gls 1.0009638620830592 0.009454711482258132

# %%
np.savez(
    'wp_results-obs-2.npz',
    rp_centers=rcen,
    wp_small=wp1_100,
    wp_err_small=wp_err1_100,
    wp_large=wp2_100,
    wp_err_large=wp_err2_100,
    ratio_mean=ratio_100,
    ratio_err=ratio_err_100,
    C_total_ratio=ratio_cov_100
)

# %%
data = np.load('wp_results-obs-2.npz')
rcen = data['rp_centers']
wp1_100 = data['wp_small']
wp_err1_100 = data['wp_err_small']
wp2_100 = data['wp_large']
wp_err2_100 = data['wp_err_large']
ratio_100 = data['ratio_mean']
ratio_err_100 = data['ratio_err']
covr_obs = data['C_total_ratio']


fig, axs = plt.subplots(
    2, 1,
    figsize=(5.5, 6.5),
    sharex=True,
    gridspec_kw={'height_ratios': [1,1]}   # 3:2:1 的高度比
)

axs[0].fill_between(rcen,wp1_100-wp_err1_100,wp1_100+wp_err1_100,alpha=0.3,color='b', label='low-$L$, all')
axs[1].fill_between(rcen,wp2_100-wp_err2_100,wp2_100+wp_err2_100,alpha=0.3,color='r', label='high-$L$, all')


data_dir="/data/liuzhj/assbias/clustering/diff_Ms/diff_ms-total/"
dir1=data_dir+"results-specz-mag-sub1-2-regA/"
dir2=data_dir+"results-specz-mag-sub2-2-regA/"
file_path = dir1 + "wp_results.npz"
data = np.load(file_path)
rcen=data['R']
njk=data['njack']
wp1_100,wp_err1_100,wp2_100,wp_err2_100,ratio_100, ratio_err_100, ratio_cov_100, ratio_jk_100 = cal_wp_bias_ratio_3(rbin = 8, pimax = 200, pimaxint=100,pibin = 200,njack = njk, outputdir1=dir1,outputdir2=dir2)
wp1_200,wp_err1_200,wp2_200,wp_err2_200,ratio_200, ratio_err_200, ratio_cov_200, ratio_jk_200 = cal_wp_bias_ratio_3(rbin = 8, pimax = 200, pimaxint=50,pibin = 200, njack = njk, outputdir1=dir1,outputdir2=dir2)


ratio_cov_100=(ratio_cov_100*(rb_ggl_var+rb_ggl**2)+rb_ggl_var*np.outer(ratio_100, ratio_100))#*np.eye(9)
ratio_cov_200=(ratio_cov_200*(rb_ggl_var+rb_ggl**2)+rb_ggl_var*np.outer(ratio_200, ratio_200))#*np.eye(9)
ratio_cov_100=shrink_cov(ratio_cov_100)
ratio_err_100=np.sqrt(np.diag(ratio_cov_100))
ratio_err_200=np.sqrt(np.diag(ratio_cov_200))
ratio_100=ratio_100*rb_ggl
ratio_200=ratio_200*rb_ggl

rb0,rb0_err=fit_constant_with_cov(ratio_100, ratio_cov_100)
print('gls',rb0,rb0_err)

file_path = dir1 + "wp_results.dat"
data = np.genfromtxt(file_path, delimiter=' ', comments='#', dtype=dtype)
rcen=data['R']

axs[0].errorbar(rcen*10**-0.01,wp1_100,yerr=wp_err1_100,label=r"low-$L$, northern",fmt='o',capsize=4,c='g')
axs[1].errorbar(rcen*10**-0.01,wp2_100,yerr=wp_err2_100,label=r"high-$L$, northern",fmt='o',capsize=4,c='m')
axs[0].set_xscale('log')
axs[0].set_yscale('log')

axs[0].tick_params(axis='both', which='both', direction='in', top=True, right=True)
axs[0].set_xlim(2.8,48)
axs[0].set_ylabel('$w_p (R)$',fontsize=14)

data_dir="/data/liuzhj/assbias/clustering/diff_Ms/diff_ms-total/"
dir1=data_dir+"results-specz-mag-sub1-2-regB/"
dir2=data_dir+"results-specz-mag-sub2-2-regB/"
file_path = dir1 + "wp_results.npz"
data = np.load(file_path)
rcen=data['R']
njk=data['njack']
wp1_100,wp_err1_100,wp2_100,wp_err2_100,ratio_100, ratio_err_100, ratio_cov_100, ratio_jk_100 = cal_wp_bias_ratio_3(rbin = 8, pimax = 200, pimaxint=100,pibin = 200,njack = njk, outputdir1=dir1,outputdir2=dir2)
wp1_200,wp_err1_200,wp2_200,wp_err2_200,ratio_200, ratio_err_200, ratio_cov_200, ratio_jk_200 = cal_wp_bias_ratio_3(rbin = 8, pimax = 200, pimaxint=50,pibin = 200, njack = njk, outputdir1=dir1,outputdir2=dir2)


ratio_cov_100=(ratio_cov_100*(rb_ggl_var+rb_ggl**2)+rb_ggl_var*np.outer(ratio_100, ratio_100))#*np.eye(9)
ratio_cov_200=(ratio_cov_200*(rb_ggl_var+rb_ggl**2)+rb_ggl_var*np.outer(ratio_200, ratio_200))#*np.eye(9)
ratio_cov_100=shrink_cov(ratio_cov_100)
ratio_err_100=np.sqrt(np.diag(ratio_cov_100))
ratio_err_200=np.sqrt(np.diag(ratio_cov_200))
ratio_100=ratio_100*rb_ggl
ratio_200=ratio_200*rb_ggl

rb0,rb0_err=fit_constant_with_cov(ratio_100, ratio_cov_100)
print('gls',rb0,rb0_err)
axs[0].errorbar(rcen*10**0.01,wp1_100,yerr=wp_err1_100,label=r"low-$L$, southern",fmt='o',capsize=4,c='fuchsia',markerfacecolor='none')
axs[1].errorbar(rcen*10**0.01,wp2_100,yerr=wp_err2_100,label=r"high-$L$, southern",fmt='o',capsize=4,c='darkorange',markerfacecolor='none')
axs[1].set_xscale('log')
axs[1].set_yscale('log')

axs[1].tick_params(axis='both', which='both', direction='in', top=True, right=True)
axs[1].set_xlim(2.8,48)
axs[1].legend(fontsize=13)
axs[0].legend(fontsize=13)
axs[1].set_ylabel('$w_p (R)$',fontsize=14)
axs[1].set_xlabel(r'$R$ [Mpc/$h$]',fontsize=14)
axs[1].grid(True, which='major', linestyle='-', alpha=0.7)
axs[1].grid(True, which='minor', linestyle='--', alpha=0.5)
axs[0].grid(True, which='major', linestyle='-', alpha=0.7)
axs[0].grid(True, which='minor', linestyle='--', alpha=0.5)


plt.subplots_adjust(wspace=0,hspace=0)
plt.savefig('wp-diff_mag-subregion.png',bbox_inches = 'tight',dpi=200)
# Out:
# 18112.0 181120.0
# 16728.0 167280.0
# 18112.0 181120.0
# 16728.0 167280.0
# gls 0.8379622043995404 0.059358216534275185
# 7400.0 74000.0
# 6448.0 64480.0
# 7400.0 74000.0
# 6448.0 64480.0
# gls 0.9256751717114297 0.07086124725762617

# %%
rb0_l=[]
rb0_err_l=[]

models=['tinker10','cole89','jing98','sheth01','seljak04','pillepich10','bhattacharya11','comparat17']

for im in range(len(models)):
    njk=100
    M1=13.42529766
    M2=13.80874081
    zz=[0.3183509812149577,0.32184142323886783]
    delta_Mh=200
    data_path1="/data/liuzhj/assbias/clustering/diff_Ms/diff_ms-total/ggl-chains-mag/"
    samples=[]
    for isig in range(2):
        file_path1 = data_path1 + "chain_10000_steps-intpl-M-c-rs-fc-bh-n"+str(isig+1)+".npz"
        data1 = np.load(file_path1)
        samples1 = np.array(data1['arr_0'])
        nburn=int(samples1.shape[0]*0.1)
        random.shuffle(samples1[nburn:,0])
        bias_t10=bias.haloBias(10**samples1[nburn:,0], zz[isig], mdef='200m', model=models[im])
        #bias_t10=ccl.massfunction.halo_bias(cosmo, 10**samples1[nburn:,0]/h, a=1/(1+zz1), overdensity=delta_Mh)
        samples.append(bias_t10)
    chains_ratio_t10=samples[0]/samples[1]
    rb_ggl=np.mean(chains_ratio_t10)
    rb_ggl_var=np.var(chains_ratio_t10)
    
    data_dir="/data/liuzhj/assbias/clustering/diff_Ms/diff_ms-total/"
    dir1=data_dir+"results-specz-mag-sub1-2/"
    dir2=data_dir+"results-specz-mag-sub2-2/"
    wp1_100,wp_err1_100,wp2_100,wp_err2_100,ratio_100, ratio_err_100, ratio_cov_100, ratio_jk_100 = cal_wp_bias_ratio_3(rbin = 8, pimax = 200, pimaxint=100,pibin = 200,njack = njk, outputdir1=dir1,outputdir2=dir2)
    
    ratio_cov_100=(ratio_cov_100*(rb_ggl_var+rb_ggl**2)+rb_ggl_var*np.outer(ratio_100, ratio_100))#*np.eye(9)
    ratio_cov_100=shrink_cov(ratio_cov_100)
    ratio_err_100=np.sqrt(np.diag(ratio_cov_100))
    ratio_100=ratio_100*rb_ggl
    
    rb0,rb0_err=fit_constant_with_cov(ratio_100, ratio_cov_100)
    print('gls',rb0,rb0_err)
    rb0_l.append(rb0)
    rb0_err_l.append(rb0_err)
# Out:
# 25512.0 255120.0
# 23176.0 231760.0
# gls 0.8847633581398253 0.05988797678913042
# 25512.0 255120.0
# 23176.0 231760.0
# gls 0.8774884338326226 0.061248938427073664
# 25512.0 255120.0
# 23176.0 231760.0
# gls 0.8807402198430988 0.060676003395816136
# 25512.0 255120.0
# 23176.0 231760.0
# gls 0.9188648464776774 0.055939528103914005
# 25512.0 255120.0
# 23176.0 231760.0
# gls 0.7922400595157784 0.07028735943968191
# 25512.0 255120.0
# 23176.0 231760.0
# gls 0.8809357928678497 0.0604067112142284
# 25512.0 255120.0
# 23176.0 231760.0
# gls 0.8958010943890302 0.05833325773525596
# 25512.0 255120.0
# 23176.0 231760.0
# gls 0.8861667780286138 0.05982384031084429

# %%
labels=['Tinker+10','Cole+89','Jing+98','Sheth+01','Seljak+04','Pillepich+10','Bhattacharya+11','Comparat+17']

plt.figure(figsize=(12,4.5))
plt.subplot(121)

plt.plot([0,9], np.ones(2), '--', c='k')
plt.errorbar(np.arange(1, len(models)+1), rb0_l, yerr=rb0_err_l, fmt='o', c='b')
#plt.xlabel("Bias Models", fontsize=14)
plt.ylabel("$r_{b0}$", fontsize=14)
plt.xlim(0.5, 8.5)

# 设置倾斜的x轴标签
plt.xticks(np.arange(1, len(labels) + 1), labels, rotation=35, ha='right',fontsize=13)

plt.subplot(122)
mm=np.logspace(12,15,20)
for i in range(len(models)):
    plt.plot(mm,bias.haloBias(mm, 0.32, mdef='200m', model=models[i]),label=labels[i])
plt.xscale('log')
plt.yscale('log')
plt.legend(fontsize=12)
plt.xlabel(r'$M_{\rm 200m}$ $[M_\odot/h]$',fontsize=14)
plt.ylabel(r'$b_h$',fontsize=14)
plt.savefig('bias_model.png',bbox_inches = 'tight',dpi=200)

# %%
M1=13.42529766
M2=13.80874081
zz1=0.3183509812149577
zz2=0.32184142323886783
delta_Mh=200
bias1=ccl.massfunction.halo_bias(cosmo, 10**M1/h, a=1/(1+zz1), overdensity=delta_Mh)
bias2=ccl.massfunction.halo_bias(cosmo, 10**M2/h, a=1/(1+zz2), overdensity=delta_Mh)
br_t10=bias1/bias2

dtype = [('R', float), ('Rmin', float), ('Rmax', float), ('wp', float), ('wp_err', float)]
fig, axs = plt.subplots(
    3, 1,
    figsize=(5.5, 8.5),
    sharex=True,
    gridspec_kw={'height_ratios': [4, 3, 1.5]}   # 3:2:1 的高度比
)

data_dir="/data/liuzhj/assbias/clustering/diff_Ms/diff_ms-total/"
dir1=data_dir+"results-specz-mag-sub1/"
dir2=data_dir+"results-specz-mag-sub2/"
wp1_100,wp_err1_100,wp2_100,wp_err2_100,ratio_100, ratio_err_100, ratio_cov_100, ratio_jk_100 = cal_wp_bias_ratio(rbin = 9, pimax = 200, pimaxint=100, bias1=bias1,bias2=bias2,pibin = 200,njack = 100, outputdir1=dir1,outputdir2=dir2)
wp1_200,wp_err1_200,wp2_200,wp_err2_200,ratio_200, ratio_err_200, ratio_cov_200, ratio_jk_200 = cal_wp_bias_ratio(rbin = 9, pimax = 200, pimaxint=50,bias1=bias1,bias2=bias2,pibin = 200, njack = 100, outputdir1=dir1,outputdir2=dir2)

rb0,rb0_err=fit_constant_with_cov(ratio_100, ratio_cov_100)
print('gls',rb0,rb0_err)


file_path = dir1 + "wp_results.dat"
data = np.genfromtxt(file_path, delimiter=' ', comments='#', dtype=dtype)
rcen=data['R']

#axs[0].plot(rcen,bias1**2*wp(rcen, 0.31),'b--')
#axs[0].plot(rcen,bias2**2*wp(rcen, 0.31),'r--')
axs[0].errorbar(rcen,wp1_100,yerr=wp_err1_100,label=r"low-$L$",fmt='o',capsize=4,c='b')
axs[0].errorbar(rcen,wp2_100,yerr=wp_err2_100,label=r"high-$L$",fmt='o',capsize=4,c='r')
axs[0].set_xscale('log')
axs[0].set_yscale('log')
    
axs[1].errorbar(rcen,ratio_100,yerr=ratio_err_100,fmt='o',capsize=4,c='m',label=r'$\Pi_{\rm max}=100{\rm Mpc}/h$')
axs[1].errorbar(rcen*1.05,ratio_200,yerr=ratio_err_200,fmt='o',capsize=4,c='gray',markerfacecolor='none',label=r'$\Pi_{\rm max}=50{\rm Mpc}/h$')
axs[1].legend(fontsize=12)

inv_ratio_cov=np.linalg.inv(ratio_cov_100)
b,bem,bep,chains_ratio = mcmcfit(rcen,ratio_100,inv_ratio_cov)
print('mcmc',b,bem,bep)

data_path1="/data/liuzhj/assbias/clustering/diff_Ms/diff_ms-total/ggl-chains-mag/"
samples=[]
for isig in range(2):
    file_path1 = data_path1 + "chain_10000_steps-intpl-M-c-rs-fc-bh-n"+str(isig+1)+".npz"
    data1 = np.load(file_path1)
    samples1 = np.array(data1['arr_0'])
    nburn=int(samples1.shape[0]*0.1)
    random.shuffle(samples1[nburn:,0])
    bias_t10=ccl.massfunction.halo_bias(cosmo, 10**samples1[nburn:,0]/h, a=1/(1+zz1), overdensity=delta_Mh)
    samples.append(bias_t10)
chains_ratio_t10=samples[0]/samples[1]

rb0,rb0_err=fit_constant_with_cov(ratio_100/br_t10, ratio_cov_100/br_t10**2)
wp_ratio=np.random.normal(loc=rb0, scale=rb0_err, size=len(chains_ratio_t10))
chains_assbias=wp_ratio*chains_ratio_t10

quantiles = np.array([16., 50., 84.])
parameter_results = np.percentile(chains_assbias, quantiles)
b = parameter_results[1]
bem = parameter_results[1] - parameter_results[0]
bep = parameter_results[2] - parameter_results[1]
print('Mh_err',b,bem,bep)

text_str = r"$r_{{b0}} = {:.2f}^{{+{:.2f}}}_{{-{:.2f}}}$".format(b, bep, bem)

diff=np.mat(ratio_100-1)
snr=np.sqrt(np.dot(diff, np.dot(inv_ratio_cov, diff.T)))[0,0]
print("S/N: ",snr)

axs[1].plot([0.1,100],np.ones(2),'--',c='k')
#axs[1].plot([0.1,100],np.ones(2)*b,'-',c='darkorange')
#axs[1].fill_between([0.1,100],np.ones(2)*(b-bem),np.ones(2)*(b+bem),alpha=0.4,color='darkorange')

axs[1].set_xscale('log')
#axs[1].text(2.3,1.1,text_str,fontsize=14)
#axs[1].text(2.3,1.25,'S/N = '+str(format(snr, '.1f')),fontsize=14)

axs[2].set_xlabel(r'$R$ [Mpc/$h$]',fontsize=14)
axs[1].set_ylim(0.78,1.2)

axs[0].tick_params(axis='both', which='both', direction='in', top=True, right=True)
axs[1].tick_params(axis='both', which='both', direction='in', top=True, right=True)
axs[2].tick_params(axis='both', which='both', direction='in', top=True, right=True)
axs[1].set_xlim(1.8,48)
axs[0].legend(fontsize=14)
axs[0].set_ylabel('$w_p (R)$',fontsize=14)
axs[1].set_ylabel('$r_b (R)$',fontsize=14)
    
ratio_ratio,cov = calcJKCov(np.transpose(np.sqrt(ratio_jk_200/ratio_jk_100)))
ratio_ratio_err = np.sqrt(np.diag(cov))


inv_ratio_cov=np.linalg.inv(cov)
diff=np.mat(ratio_ratio-1)
snr=np.sqrt(np.dot(diff, np.dot(inv_ratio_cov, diff.T)))[0,0]
print("S/N: ",snr)

axs[2].plot([0.1,100],np.ones(2),'-',c='gray')
axs[2].errorbar(rcen,ratio_ratio,yerr=ratio_ratio_err,fmt='s',capsize=4,c='m',markerfacecolor='none')
axs[2].set_ylim(0.9,1.12)
axs[2].set_ylabel(r'$r_b^{\rm 50}/r_b^{\rm 100}$',fontsize=14)

plt.subplots_adjust(wspace=0,hspace=0)
plt.savefig('wp-diff_mag-specz.png',bbox_inches = 'tight',dpi=200)
# Out:
# 25512.0 255120.0
# 23176.0 231760.0
# 25512.0 255120.0
# 23176.0 231760.0
# gls 0.9041850484792477 0.02515261517731788
# 100%|██████████| 5000/5000 [00:02<00:00, 2307.59it/s]
# mcmc 0.9043135499968269 0.02533961941794627 0.025094492156832127
# Mh_err 0.9083843123414378 0.057353158145015404 0.06745153919351343
# S/N:  4.445234380239653
# S/N:  2.7518216423217026

# %%
import numpy as np

def build_Cr_from_chain_and_jk(B_chain, y_jk_samples, jitter=1e-12, use_log=True):
    """
    Parameters
    ----------
    B_chain : array_like, shape (N_chain,)
        MCMC samples of B = b_low / b_high.
    y_jk_samples : array_like, shape (N_jk, nR)
        Jackknife realizations of y(R) = sqrt(wp_high/wp_low) or similar.
    jitter : float
        Small diagonal jitter to add if covariance not PSD.
    use_log : bool
        If True, compute sigma_ln from ln(B) chain and mu_B = exp(mean(ln B)).
        If False, use mu_B = mean(B) and sigma_B/ mu_B approx for sigma_ln.
    Returns
    -------
    mu_B : float
    sigma_lnB2 : float
    y_mean : ndarray (nR,)
    C_y : ndarray (nR, nR)
    r_hat : ndarray (nR,)
    C_r : ndarray (nR, nR)
    """
    B_chain = np.asarray(B_chain)
    y_jk = np.asarray(y_jk_samples)
    nJK, nR = y_jk.shape

    # 1) compute mu_B and sigma_lnB^2
    if use_log:
        lnB = np.log(B_chain)
        mean_lnB = lnB.mean()
        sigma_lnB2 = lnB.var(ddof=1)
        mu_B = np.exp(mean_lnB)
    else:
        mu_B = B_chain.mean()
        sigma_B2 = B_chain.var(ddof=1)
        sigma_lnB2 = (sigma_B2 / mu_B**2)  # approx for small rel error

    # 2) JK mean and covariance for y
    y_mean = y_jk.mean(axis=0)
    # jackknife covariance (standard JK factor)
    diffs = y_jk - y_mean[None, :]
    C_y = (nJK - 1) / nJK * (diffs.T @ diffs)

    # 3) assemble r_hat and Cr
    r_hat = mu_B * y_mean
    C_r = (mu_B**2) * C_y + sigma_lnB2 * np.outer(r_hat, r_hat)

    # 4) ensure symmetry and PSD (add tiny jitter if necessary)
    C_r = 0.5 * (C_r + C_r.T)  # enforce symmetry
    # check eigenvalues
    eig = np.linalg.eigvalsh(C_r)
    min_eig = eig.min()
    if min_eig < -1e-12:
        # if significantly negative, add more jitter
        add = (-min_eig + 1e-12)
        C_r += add * np.eye(nR)
    elif min_eig < 1e-15:
        C_r += jitter * np.eye(nR)

    return r_hat, C_r

def shrink_cov(C):
    lamb = 0.05
    return (1-lamb)*C + lamb*np.diag(np.diag(C))

# %%
def sample_mvnormal_ones_mean(mu,cov, n_samples=10000, random_state=None):
    """
    Draw samples from N(mu, cov) with mu = [1,1,...,1].
    """
    cov = np.asarray(cov)
    d = cov.shape[0]

    rng = np.random.default_rng(random_state)
    X = rng.multivariate_normal(mean=mu, cov=cov, size=n_samples, check_valid='raise')
    return X

def cov_random_chains(ratio,ratio_cov,chains_ratio,n_samples):
    X = sample_mvnormal_ones_mean(ratio,ratio_cov, n_samples=n_samples, random_state=42)
    meanX=X.mean(axis=0)
    covX= np.cov(X, rowvar=False)
    errX=np.sqrt(np.diagonal(covX))
    
    X2=np.zeros_like(X)
    for i in range(len(rcen)):
        X2[:,i]=X[:,i]*np.random.choice(chains_ratio, size=n_samples, replace=False)
    meanX=X2.mean(axis=0)
    covX= np.cov(X2, rowvar=False)
    errX=np.sqrt(np.diagonal(covX))
    return meanX,covX,errX

# %%
njk=100
zz1=0.3183509812149577
zz2=0.32184142323886783
delta_Mh=200
data_path1="/data/liuzhj/assbias/clustering/diff_Ms/diff_ms-total/ggl-chains-mag/"
samples=[]
for isig in range(2):
    file_path1 = data_path1 + "chain_10000_steps-intpl-M-c-rs-fc-bh-n"+str(isig+1)+".npz"
    data1 = np.load(file_path1)
    samples1 = np.array(data1['arr_0'])
    nburn=int(samples1.shape[0]*0.1)
    random.shuffle(samples1[nburn:,0])
    bias_t10=ccl.massfunction.halo_bias(cosmo, 10**samples1[nburn:,0]/h, a=1/(1+zz1), overdensity=delta_Mh)
    samples.append(bias_t10)
chains_ratio_t10=samples[0]/samples[1]
rb_ggl=np.mean(chains_ratio_t10)
rb_ggl_var=np.var(chains_ratio_t10)

dtype = [('R', float), ('Rmin', float), ('Rmax', float), ('wp', float), ('wp_err', float)]
fig, axs = plt.subplots(
    3, 1,
    figsize=(5.5, 8.5),
    sharex=True,
    gridspec_kw={'height_ratios': [4, 3, 1.5]}   # 3:2:1 的高度比
)

data_dir="/data/liuzhj/assbias/clustering/diff_Ms/diff_ms-total/"
dir1=data_dir+"results-specz-mag-sub1/"
dir2=data_dir+"results-specz-mag-sub2/"
wp1_100,wp_err1_100,wp2_100,wp_err2_100,ratio_100, ratio_err_100, ratio_cov_100, ratio_jk_100 = cal_wp_bias_ratio_3(rbin = 9, pimax = 200, pimaxint=50,pibin = 200,njack = njk, outputdir1=dir1,outputdir2=dir2)
wp1_200,wp_err1_200,wp2_200,wp_err2_200,ratio_200, ratio_err_200, ratio_cov_200, ratio_jk_200 = cal_wp_bias_ratio_3(rbin = 9, pimax = 200, pimaxint=100,pibin = 200, njack = njk, outputdir1=dir1,outputdir2=dir2)


ratio_100,ratio_cov_100,ratio_err_100=cov_random_chains(ratio_100,ratio_cov_100,chains_ratio_t10,n_samples=800)
ratio_200,ratio_cov_200,ratio_err_200=cov_random_chains(ratio_200,ratio_cov_200,chains_ratio_t10,n_samples=800)

#ratio_100,ratio_cov_100=build_Cr_from_chain_and_jk(chains_ratio_t10, ratio_jk_100, jitter=1e-12, use_log=False)
#ratio_cov_100=shrink_cov(ratio_cov_100)
#ratio_err_100=np.sqrt(np.diag(ratio_cov_100))


rb0,rb0_err=fit_constant_with_cov(ratio_100, ratio_cov_100)
print('gls',rb0,rb0_err)

file_path = dir1 + "wp_results.dat"
data = np.genfromtxt(file_path, delimiter=' ', comments='#', dtype=dtype)
rcen=data['R']

#axs[0].plot(rcen,bias1**2*wp(rcen, 0.31),'b--')
#axs[0].plot(rcen,bias2**2*wp(rcen, 0.31),'r--')
axs[0].errorbar(rcen,wp1_100,yerr=wp_err1_100,label=r"low-$L$",fmt='o',capsize=4,c='b')
axs[0].errorbar(rcen,wp2_100,yerr=wp_err2_100,label=r"high-$L$",fmt='o',capsize=4,c='r')
axs[0].set_xscale('log')
axs[0].set_yscale('log')
    
axs[1].errorbar(rcen,ratio_100,yerr=ratio_err_100,fmt='o',capsize=4,c='m',label=r'$\Pi_{\rm max}=50{\rm Mpc}/h$')
axs[1].errorbar(rcen*1.05,ratio_200,yerr=ratio_err_200,fmt='o',capsize=4,c='gray',markerfacecolor='none',label=r'$\Pi_{\rm max}=100{\rm Mpc}/h$')
axs[1].legend(fontsize=12)

inv_ratio_cov=np.linalg.inv(ratio_cov_100)
b,bem,bep,chains22 = mcmcfit(rcen,ratio_100,inv_ratio_cov)
print(b,bem,bep)
text_str = r"$r_{{w0}} = {:.2f}^{{+{:.2f}}}_{{-{:.2f}}}$".format(b, bep, bem)

diff=np.mat(ratio_100-1)
#snr=np.sqrt(np.dot(diff, np.dot(inv_ratio_cov, diff.T)))[0,0]
print("S/N: ",snr)

axs[1].plot([0.1,100],np.ones(2),'--',c='k')
axs[1].plot([0.1,100],np.ones(2)*b,'-',c='darkorange')
axs[1].fill_between([0.1,100],np.ones(2)*(b-bem),np.ones(2)*(b+bem),alpha=0.4,color='darkorange')

axs[1].set_xscale('log')
axs[1].text(2.3,1.1,text_str,fontsize=14)
#axs[1].text(2.3,1.25,'S/N = '+str(format(snr, '.1f')),fontsize=14)

axs[2].set_xlabel(r'$R$ [Mpc/$h$]',fontsize=14)
axs[1].set_ylim(0.7,1.3)

axs[0].tick_params(axis='both', which='both', direction='in', top=True, right=True)
axs[1].tick_params(axis='both', which='both', direction='in', top=True, right=True)
axs[2].tick_params(axis='both', which='both', direction='in', top=True, right=True)
axs[1].set_xlim(1.8,48)
axs[0].legend(fontsize=14)
axs[0].set_ylabel('$w_p (R)$',fontsize=14)
axs[1].set_ylabel('$r_b (R)$',fontsize=14)
    
ratio_ratio,cov = calcJKCov(np.transpose(np.sqrt(ratio_jk_200/ratio_jk_100)))
ratio_ratio_err = np.sqrt(np.diag(cov))


inv_ratio_cov=np.linalg.inv(cov)
diff=np.mat(ratio_ratio-1)
snr=np.sqrt(np.dot(diff, np.dot(inv_ratio_cov, diff.T)))[0,0]
print("S/N: ",snr)

axs[2].plot([0.1,100],np.ones(2),'-',c='gray')
axs[2].errorbar(rcen,ratio_ratio,yerr=ratio_ratio_err,fmt='o',capsize=4,c='m')
axs[2].set_ylim(0.93,1.07)
axs[2].set_ylabel(r'$r_b^{\rm 100}/r_b^{\rm 50}$',fontsize=14)

plt.subplots_adjust(wspace=0,hspace=0)
plt.savefig('wp-diff_mag-specz.png',bbox_inches = 'tight',dpi=200)
# Out:
# 25512.0 255120.0
# 23176.0 231760.0
# 25512.0 255120.0
# 23176.0 231760.0
# gls 0.9104528372441346 0.028377249638369195
# 100%|██████████| 5000/5000 [00:02<00:00, 2219.85it/s]
# 0.9103754699780482 0.027863449602104184 0.028991948248706878
# S/N:  2.7612608185904937
# S/N:  2.7612608185904937

# %%
def corr(mat):
    mat2=np.zeros_like(mat)
    for i in range(mat.shape[0]):
        for j in range(mat.shape[1]):
            mat2[i,j]=mat[i,j]/np.sqrt(mat[i,i]*mat[j,j])
    return mat2

# %%
plt.imshow(corr(np.cov(X, rowvar=False)))
plt.colorbar()

# %%
def cal_wp_bias_ratio_2(rbin, pimax, pibin,pimaxint,biasr,njack, outputdir1,outputdir2):
    deltapi= float(pimax)/float(pibin)
    
    dd_file=outputdir1+"pairs_dd.dat"
    dr_file=outputdir1+"pairs_dr.dat"
    rr_file=outputdir1+"pairs_rr.dat"
    data=np.loadtxt(outputdir1+"num_gal_ran.dat")
    ngal=data[0]
    nran=data[1]
    print(ngal,nran)
    dd = np.fromfile(dd_file, dtype = float)
    dd = decodePairs(dd, njack, rbin, pibin)/(ngal*ngal)
    dr = np.fromfile(dr_file, dtype = float)
    dr = decodePairs(dr, njack, rbin, pibin)/(ngal*nran)
    rr = np.fromfile(rr_file, dtype = float)
    rr = decodePairs(rr, njack, rbin, pibin)/(nran*nran)

    xi = (dd - 2.*dr + rr)/rr
    #xi = dd/rr-1
    wp_jk1 = 2.*np.sum(xi[:,:,:pimaxint], axis = 2)*deltapi
    wp1,cov1 = calcJKCov(np.transpose(wp_jk1))

    dd_file=outputdir2+"pairs_dd.dat"
    dr_file=outputdir2+"pairs_dr.dat"
    rr_file=outputdir2+"pairs_rr.dat"
    data=np.loadtxt(outputdir2+"num_gal_ran.dat")
    ngal=data[0]
    nran=data[1]
    print(ngal,nran)
    dd = np.fromfile(dd_file, dtype = float)
    dd = decodePairs(dd, njack, rbin, pibin)/(ngal*ngal)
    dr = np.fromfile(dr_file, dtype = float)
    dr = decodePairs(dr, njack, rbin, pibin)/(ngal*nran)
    rr = np.fromfile(rr_file, dtype = float)
    rr = decodePairs(rr, njack, rbin, pibin)/(nran*nran)

    xi = (dd - 2.*dr + rr)/rr
    #xi = dd/rr-1
    wp_jk2 = 2.*np.sum(xi[:,:,:pimaxint], axis = 2)*deltapi
    wp2,cov2 = calcJKCov(np.transpose(wp_jk2))

    biasr2=np.zeros_like(wp_jk2)
    for i in range(wp_jk2.shape[1]):
        biasr2[:,i]=np.random.choice(biasr, size=njack, replace=False)
    ratio,cov = calcJKCov(np.transpose(biasr2*np.sqrt(wp_jk2/wp_jk1)))
    return wp1,np.sqrt(np.diag(cov1)),wp2,np.sqrt(np.diag(cov2)),ratio, np.sqrt(np.diag(cov)),cov, wp_jk1/wp_jk2*biasr2**2



njk=100
zz1=0.3183509812149577
zz2=0.32184142323886783
delta_Mh=200
data_path1="/data/liuzhj/assbias/clustering/diff_Ms/diff_ms-total/ggl-chains-mag/"
samples=[]
for isig in range(2):
    file_path1 = data_path1 + "chain_10000_steps-intpl-M-c-rs-fc-bh-n"+str(isig+1)+".npz"
    data1 = np.load(file_path1)
    samples1 = np.array(data1['arr_0'])
    nburn=int(samples1.shape[0]*0.1)
    random.shuffle(samples1[nburn:,0])
    bias_t10=ccl.massfunction.halo_bias(cosmo, 10**samples1[nburn:,0]/h, a=1/(1+zz1), overdensity=delta_Mh)
    samples.append(bias_t10)
chains_ratio_t10=samples[0]/samples[1]
print(chains_ratio_t10.shape,np.mean(chains_ratio_t10))

dtype = [('R', float), ('Rmin', float), ('Rmax', float), ('wp', float), ('wp_err', float)]
fig, axs = plt.subplots(
    3, 1,
    figsize=(5.5, 8.5),
    sharex=True,
    gridspec_kw={'height_ratios': [4, 3, 1.5]}   # 3:2:1 的高度比
)

data_dir="/data/liuzhj/assbias/clustering/diff_Ms/diff_ms-total/"
dir1=data_dir+"results-specz-mag-sub1/"
dir2=data_dir+"results-specz-mag-sub2/"
wp1_100,wp_err1_100,wp2_100,wp_err2_100,ratio_100, ratio_err_100, ratio_cov_100, ratio_jk_100 = cal_wp_bias_ratio_2(rbin = 9, pimax = 200, pimaxint=50,pibin = 200,biasr=chains_ratio_t10,njack = njk, outputdir1=dir1,outputdir2=dir2)
wp1_200,wp_err1_200,wp2_200,wp_err2_200,ratio_200, ratio_err_200, ratio_cov_200, ratio_jk_200 = cal_wp_bias_ratio_2(rbin = 9, pimax = 200, pimaxint=100,pibin = 200,biasr=chains_ratio_t10, njack = njk, outputdir1=dir1,outputdir2=dir2)

file_path = dir1 + "wp_results.dat"
data = np.genfromtxt(file_path, delimiter=' ', comments='#', dtype=dtype)
rcen=data['R']

#axs[0].plot(rcen,bias1**2*wp(rcen, 0.31),'b--')
#axs[0].plot(rcen,bias2**2*wp(rcen, 0.31),'r--')
axs[0].errorbar(rcen,wp1_100,yerr=wp_err1_100,label=r"low-$L$",fmt='o',capsize=4,c='b')
axs[0].errorbar(rcen,wp2_100,yerr=wp_err2_100,label=r"high-$L$",fmt='o',capsize=4,c='r')
axs[0].set_xscale('log')
axs[0].set_yscale('log')
    
axs[1].errorbar(rcen,ratio_100,yerr=ratio_err_100,fmt='o',capsize=4,c='m',label=r'$\Pi_{\rm max}=50{\rm Mpc}/h$')
axs[1].errorbar(rcen*1.05,ratio_200,yerr=ratio_err_200,fmt='o',capsize=4,c='gray',markerfacecolor='none',label=r'$\Pi_{\rm max}=100{\rm Mpc}/h$')
axs[1].legend(fontsize=12)

inv_ratio_cov=np.linalg.inv(ratio_cov_100)
b,bem,bep,_ = mcmcfit(rcen,ratio_100,inv_ratio_cov)
print(b,bem,bep)
text_str = r"$r_{{w0}} = {:.2f}^{{+{:.2f}}}_{{-{:.2f}}}$".format(b, bep, bem)

diff=np.mat(ratio_100-1)
snr=np.sqrt(np.dot(diff, np.dot(inv_ratio_cov, diff.T)))[0,0]
print("S/N: ",snr)

axs[1].plot([0.1,100],np.ones(2),'--',c='k')
axs[1].plot([0.1,100],np.ones(2)*b,'-',c='darkorange')
axs[1].fill_between([0.1,100],np.ones(2)*(b-bem),np.ones(2)*(b+bem),alpha=0.4,color='darkorange')

axs[1].set_xscale('log')
axs[1].text(2.3,1.1,text_str,fontsize=14)
#axs[1].text(2.3,1.25,'S/N = '+str(format(snr, '.1f')),fontsize=14)

axs[2].set_xlabel(r'$R$ [Mpc/$h$]',fontsize=14)
#axs[1].set_ylim(0.7,1.3)

axs[0].tick_params(axis='both', which='both', direction='in', top=True, right=True)
axs[1].tick_params(axis='both', which='both', direction='in', top=True, right=True)
axs[2].tick_params(axis='both', which='both', direction='in', top=True, right=True)
axs[1].set_xlim(1.8,48)
axs[0].legend(fontsize=14)
axs[0].set_ylabel('$w_p (R)$',fontsize=14)
axs[1].set_ylabel('$r_b (R)$',fontsize=14)
    
ratio_ratio,cov = calcJKCov(np.transpose(np.sqrt(ratio_jk_200/ratio_jk_100)))
ratio_ratio_err = np.sqrt(np.diag(cov))


inv_ratio_cov=np.linalg.inv(cov)
diff=np.mat(ratio_ratio-1)
snr=np.sqrt(np.dot(diff, np.dot(inv_ratio_cov, diff.T)))[0,0]
print("S/N: ",snr)

axs[2].plot([0.1,100],np.ones(2),'-',c='gray')
axs[2].errorbar(rcen,ratio_ratio,yerr=ratio_ratio_err,fmt='o',capsize=4,c='m')
#axs[2].set_ylim(0.85,1.15)
axs[2].set_ylabel(r'$r_b^{\rm 100}/r_b^{\rm 50}$',fontsize=14)

plt.subplots_adjust(wspace=0,hspace=0)
plt.savefig('wp-diff_mag-specz.png',bbox_inches = 'tight',dpi=200)
# Out:
# (360000,) 0.7607911288351596
# 25512.0 255120.0
# 23176.0 231760.0
# 25512.0 255120.0
# 23176.0 231760.0
# 100%|██████████| 5000/5000 [00:02<00:00, 2239.13it/s]
# 0.904202532779868 0.1659297344213384 0.1709359301276876
# S/N:  0.5476891722111003
# S/N:  0.10465644467827499

# %%
M1=13.51864804
M2=13.66428429
bias1=ccl.massfunction.halo_bias(cosmo, 10**M1/h, a=1/(1+0.31), overdensity=180)
bias2=ccl.massfunction.halo_bias(cosmo, 10**M2/h, a=1/(1+0.31), overdensity=180)

dtype = [('R', float), ('Rmin', float), ('Rmax', float), ('wp', float), ('wp_err', float)]

fig,axs=plt.subplots(2,1,figsize=(5,3.5*2), sharex=True)

data_dir="/data/liuzhj/assbias/clustering/diff_Ms/diff_ms-total/"
dir1=data_dir+"results-specz-color-sub1/"
dir2=data_dir+"results-specz-color-sub2/"
wp1_100,wp_err1_100,wp2_100,wp_err2_100,ratio_100, ratio_err_100, ratio_cov_100, ratio_jk_100 = cal_wp_bias_ratio(rbin = 9, pimax = 200, pimaxint=50, bias1=bias1,bias2=bias2,pibin = 200,njack = 100, outputdir1=dir1,outputdir2=dir2)
wp1_200,wp_err1_200,wp2_200,wp_err2_200,ratio_200, ratio_err_200, ratio_cov_200, ratio_jk_200 = cal_wp_bias_ratio(rbin = 9, pimax = 200, pimaxint=100,bias1=bias1,bias2=bias2,pibin = 200, njack = 100, outputdir1=dir1,outputdir2=dir2)

file_path = dir1 + "wp_results.dat"
data = np.genfromtxt(file_path, delimiter=' ', comments='#', dtype=dtype)
rcen=data['R']

axs[0].plot(rcen,bias1**2*wp(rcen, 0.31),'b--')
axs[0].plot(rcen,bias2**2*wp(rcen, 0.31),'r--')
axs[0].errorbar(rcen,wp1_100,yerr=wp_err1_100,label=r"low-$M_*$",fmt='o',capsize=4,c='b')
axs[0].errorbar(rcen,wp2_100,yerr=wp_err2_100,label=r"high-$M_*$",fmt='o',capsize=4,c='r')
axs[0].set_xscale('log')
axs[0].set_yscale('log')
    
axs[1].errorbar(rcen*1.05,ratio_200,yerr=ratio_err_200,fmt='o',capsize=4,c='gray',markerfacecolor='none')
axs[1].errorbar(rcen,ratio_100,yerr=ratio_err_100,fmt='o',capsize=4,c='m')

inv_ratio_cov=np.linalg.inv(ratio_cov_100)
b,bem,bep = mcmcfit(rcen,ratio_100,inv_ratio_cov)
print(b,bem,bep)
text_str = r"$r_{{w0}} = {:.2f}^{{+{:.2f}}}_{{-{:.2f}}}$".format(b, bep, bem)

diff=np.mat(ratio_100-1)
snr=np.sqrt(np.dot(diff, np.dot(inv_ratio_cov, diff.T)))[0,0]
print("S/N: ",snr)

axs[1].plot([0.1,100],np.ones(2),'-',c='gray')
axs[1].plot([0.1,100],np.ones(2)*b,'-',c='darkorange')
axs[1].fill_between([0.1,100],np.ones(2)*(b-bem),np.ones(2)*(b+bem),alpha=0.4,color='darkorange')

axs[1].set_xscale('log')
axs[1].text(2.3,1.8,text_str,fontsize=14)
axs[1].text(2.3,1.7,'S/N = '+str(format(snr, '.1f')),fontsize=14)

axs[1].set_xlabel(r'$R$ [Mpc/$h$]',fontsize=14)
axs[1].set_ylim(0.7,1.4)

axs[0].tick_params(axis='both', which='both', direction='in', top=True, right=True)
axs[1].tick_params(axis='both', which='both', direction='in', top=True, right=True)
axs[1].set_xlim(1.8,48)
axs[0].legend(fontsize=14)
axs[0].set_ylabel('$w_p (R)$',fontsize=14)
axs[1].set_ylabel('$r_w (R)$',fontsize=14)
    
plt.subplots_adjust(wspace=0,hspace=0)
plt.savefig('wp-diff_mag-specz.png',bbox_inches = 'tight',dpi=200)


ratio_ratio,cov = calcJKCov(np.transpose(np.sqrt(ratio_jk_200/ratio_jk_100)))
ratio_ratio_err = np.sqrt(np.diag(cov))


inv_ratio_cov=np.linalg.inv(cov)
diff=np.mat(ratio_ratio-1)
snr=np.sqrt(np.dot(diff, np.dot(inv_ratio_cov, diff.T)))[0,0]
print("S/N: ",snr)

plt.figure()
plt.plot([0.1,100],np.ones(2),'-',c='gray')
plt.errorbar(rcen,ratio_ratio,yerr=ratio_ratio_err,fmt='o',capsize=4,c='m')
plt.xlim(1.8,48)
plt.xscale('log')
plt.xlabel(r'$R$ [Mpc/$h$]',fontsize=14)
# Out:
# 23129.0 231290.0
# 25559.0 255590.0
# 23129.0 231290.0
# 25559.0 255590.0
# 100%|██████████| 5000/5000 [00:02<00:00, 2237.05it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-145-0fd2404415ea> in <module>
#      29
#      30 inv_ratio_cov=np.linalg.inv(ratio_cov_100)
# ---> 31 b,bem,bep = mcmcfit(rcen,ratio_100,inv_ratio_cov)
#      32 print(b,bem,bep)
#      33 text_str = r"$r_{{w0}} = {:.2f}^{{+{:.2f}}}_{{-{:.2f}}}$".format(b, bep, bem)
#
# ValueError: too many values to unpack (expected 3)

# %%
M1=13.44498904
M2=13.87708763
bias1=ccl.massfunction.halo_bias(cosmo, 10**M1/h, a=1/(1+0.31), overdensity=180)
bias2=ccl.massfunction.halo_bias(cosmo, 10**M2/h, a=1/(1+0.31), overdensity=180)

dtype = [('R', float), ('Rmin', float), ('Rmax', float), ('wp', float), ('wp_err', float)]

fig,axs=plt.subplots(2,1,figsize=(5,3.5*2), sharex=True)

data_dir="/data/liuzhj/assbias/clustering/diff_Ms/diff_ms-total/"
dir1=data_dir+"results-specz-logMs-sub1/"
dir2=data_dir+"results-specz-logMs-sub2/"
wp1_100,wp_err1_100,wp2_100,wp_err2_100,ratio_100, ratio_err_100, ratio_cov_100, ratio_jk_100 = cal_wp_bias_ratio(rbin = 9, pimax = 200, pimaxint=50, bias1=bias1,bias2=bias2,pibin = 200,njack = 100, outputdir1=dir1,outputdir2=dir2)
wp1_200,wp_err1_200,wp2_200,wp_err2_200,ratio_200, ratio_err_200, ratio_cov_200, ratio_jk_200 = cal_wp_bias_ratio(rbin = 9, pimax = 200, pimaxint=100,bias1=bias1,bias2=bias2,pibin = 200, njack = 100, outputdir1=dir1,outputdir2=dir2)

file_path = dir1 + "wp_results.dat"
data = np.genfromtxt(file_path, delimiter=' ', comments='#', dtype=dtype)
rcen=data['R']

axs[0].plot(rcen,bias1**2*wp(rcen, 0.31),'b--')
axs[0].plot(rcen,bias2**2*wp(rcen, 0.31),'r--')
axs[0].errorbar(rcen,wp1_100,yerr=wp_err1_100,label=r"low-$M_*$",fmt='o',capsize=4,c='b')
axs[0].errorbar(rcen,wp2_100,yerr=wp_err2_100,label=r"high-$M_*$",fmt='o',capsize=4,c='r')
axs[0].set_xscale('log')
axs[0].set_yscale('log')
    
axs[1].errorbar(rcen*1.05,ratio_200,yerr=ratio_err_200,fmt='o',capsize=4,c='gray',markerfacecolor='none')
axs[1].errorbar(rcen,ratio_100,yerr=ratio_err_100,fmt='o',capsize=4,c='m')

inv_ratio_cov=np.linalg.inv(ratio_cov_100)
b,bem,bep = mcmcfit(rcen,ratio_100,inv_ratio_cov)
print(b,bem,bep)
text_str = r"$r_{{w0}} = {:.2f}^{{+{:.2f}}}_{{-{:.2f}}}$".format(b, bep, bem)

diff=np.mat(ratio_100-1)
snr=np.sqrt(np.dot(diff, np.dot(inv_ratio_cov, diff.T)))[0,0]
print("S/N: ",snr)

axs[1].plot([0.1,100],np.ones(2),'-',c='gray')
axs[1].plot([0.1,100],np.ones(2)*b,'-',c='darkorange')
axs[1].fill_between([0.1,100],np.ones(2)*(b-bem),np.ones(2)*(b+bem),alpha=0.4,color='darkorange')

axs[1].set_xscale('log')
axs[1].text(2.3,1.8,text_str,fontsize=14)
axs[1].text(2.3,1.7,'S/N = '+str(format(snr, '.1f')),fontsize=14)

axs[1].set_xlabel(r'$R$ [Mpc/$h$]',fontsize=14)
axs[1].set_ylim(0.7,1.4)

axs[0].tick_params(axis='both', which='both', direction='in', top=True, right=True)
axs[1].tick_params(axis='both', which='both', direction='in', top=True, right=True)
axs[1].set_xlim(1.8,48)
axs[0].legend(fontsize=14)
axs[0].set_ylabel('$w_p (R)$',fontsize=14)
axs[1].set_ylabel('$r_w (R)$',fontsize=14)
    
plt.subplots_adjust(wspace=0,hspace=0)
plt.savefig('wp-diff_mag-specz.png',bbox_inches = 'tight',dpi=200)


ratio_ratio,cov = calcJKCov(np.transpose(np.sqrt(ratio_jk_200/ratio_jk_100)))
ratio_ratio_err = np.sqrt(np.diag(cov))


inv_ratio_cov=np.linalg.inv(cov)
diff=np.mat(ratio_ratio-1)
snr=np.sqrt(np.dot(diff, np.dot(inv_ratio_cov, diff.T)))[0,0]
print("S/N: ",snr)

plt.figure()
plt.plot([0.1,100],np.ones(2),'-',c='gray')
plt.errorbar(rcen,ratio_ratio,yerr=ratio_ratio_err,fmt='o',capsize=4,c='m')
plt.xlim(1.8,48)
plt.xscale('log')
plt.xlabel(r'$R$ [Mpc/$h$]',fontsize=14)
# Out:
# 23907.0 239070.0
# 18424.0 184240.0
# 23907.0 239070.0
# 18424.0 184240.0
# 100%|██████████| 5000/5000 [00:02<00:00, 2181.99it/s]
# 1.1156471982801592 0.02447141141822362 0.0249428604594657
# S/N:  5.608249141027775
# S/N:  2.2470741266529517
# Text(0.5, 0, '$R$ [Mpc/$h$]')

# %%
def cal_wp_bias_ratio(rbin, pimax, pibin, njack, suffix1, suffix2, data_dir):
    deltapi= float(pimax)/float(pibin)
    
    outputdir=data_dir+"results-specz-small_Ms/"
    dd_file=outputdir+"pairs_dd.dat"
    dr_file=outputdir+"pairs_dr.dat"
    rr_file=outputdir+"pairs_rr.dat"
    data=np.loadtxt(outputdir+"num_gal_ran.dat")
    ngal=data[0]
    nran=data[1]
    print(ngal,nran)
    dd = np.fromfile(dd_file, dtype = float)
    dd = decodePairs(dd, njack, rbin, pibin)/(ngal*ngal)
    dr = np.fromfile(dr_file, dtype = float)
    dr = decodePairs(dr, njack, rbin, pibin)/(ngal*nran)
    rr = np.fromfile(rr_file, dtype = float)
    rr = decodePairs(rr, njack, rbin, pibin)/(nran*nran)

    xi = (dd - 2.*dr + rr)/rr
    #xi = dd/rr-1
    wp_jk1 = 2.*np.sum(xi[:,:,100:], axis = 2)*deltapi
    wp1,cov1 = calcJKCov(np.transpose(wp_jk1))

    outputdir=data_dir+"results-specz-large_Ms/"
    dd_file=outputdir+"pairs_dd.dat"
    dr_file=outputdir+"pairs_dr.dat"
    rr_file=outputdir+"pairs_rr.dat"
    data=np.loadtxt(outputdir+"num_gal_ran.dat")
    ngal=data[0]
    nran=data[1]
    print(ngal,nran)
    dd = np.fromfile(dd_file, dtype = float)
    dd = decodePairs(dd, njack, rbin, pibin)/(ngal*ngal)
    dr = np.fromfile(dr_file, dtype = float)
    dr = decodePairs(dr, njack, rbin, pibin)/(ngal*nran)
    rr = np.fromfile(rr_file, dtype = float)
    rr = decodePairs(rr, njack, rbin, pibin)/(nran*nran)

    xi = (dd - 2.*dr + rr)/rr
    #xi = dd/rr-1
    wp_jk2 = 2.*np.sum(xi[:,:,100:], axis = 2)*deltapi
    wp2,cov2 = calcJKCov(np.transpose(wp_jk2))

    ratio,cov = calcJKCov(np.transpose(np.sqrt(wp_jk1/wp_jk2)))
    return wp1,np.sqrt(np.diag(cov1)),wp2,np.sqrt(np.diag(cov2)),ratio, np.sqrt(np.diag(cov))

# %%
imh=2
data_dir="/data/liuzhj/assbias/clustering/diff_Ms/diff_ms-total/"
wp1,wp_err1,wp2,wp_err2,ratio, ratio_err = cal_wp_bias_ratio(rbin = 9, pimax = 200, pibin = 200, njack = 100, suffix1="-small_Ms", suffix2="-large_Ms", data_dir=data_dir)

plt.errorbar(rcen,wp1,yerr=wp_err1,label=r"small-$M_*$",fmt='o',capsize=4,c='b')
plt.errorbar(rcen,wp2,yerr=wp_err2,label=r"large-$M_*$",fmt='o',capsize=4,c='r')
plt.xscale('log')
plt.plot(rcen,rcen-rcen)
plt.ylim(-20,20)
# Out:
# 12427.0 124270.0
# 12475.0 124750.0
# <ipython-input-34-de4a1d45e08c>:44: RuntimeWarning: invalid value encountered in sqrt
#   ratio,cov = calcJKCov(np.transpose(np.sqrt(wp_jk1/wp_jk2)))
# (-20.0, 20.0)

# %%
plt.errorbar(rcen1,wp1,yerr=wp_err1,label=r"small-$M_*$",fmt='o',capsize=4,c='b')
plt.errorbar(rcen2,wp2,yerr=wp_err2,label=r"large-$M_*$",fmt='o',capsize=4,c='r')
plt.xscale('log')
plt.yscale('log')
plt.plot(rcen1,rcen1-rcen1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-f67763b9035c> in <module>
# ----> 1 plt.errorbar(rcen1,wp1,yerr=wp_err1,label=r"small-$M_*$",fmt='o',capsize=4,c='b')
#       2 plt.errorbar(rcen2,wp2,yerr=wp_err2,label=r"large-$M_*$",fmt='o',capsize=4,c='r')
#       3 plt.xscale('log')
#       4 plt.yscale('log')
#       5 plt.plot(rcen1,rcen1-rcen1)
#
# NameError: name 'rcen1' is not defined

# %%
plt.errorbar(rcen2,ratio,yerr=ratio_err,label=r"large-$M_*$",fmt='o',capsize=4,c='r')
plt.xscale('log')
